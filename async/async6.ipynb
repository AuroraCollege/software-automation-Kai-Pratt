# %% [markdown]
# # Modelling Gradient Descent
#
# Here we will create a simple algorithm that uses gradient descent to optimise a simple linear regression model.
# The data are fetched from the [BOM](http://www.bom.gov.au/climate/data/index.shtml) and show temperatures for the Sydney (Kinsford Smith) and Newcastle (Williamstown RAAF) airports.

# %%
# Import dependancies 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
fulldataset = pd.read_csv('../datasets/AirportTemps.csv')
dataset = fulldataset.dropna()

# Plot the data (to observe correlation)
plt.scatter(dataset['MaxTempNewcastleAirport'],dataset['MaxTempSydneyAirport'],marker='x')
plt.xlabel('NCastle Temp')
plt.ylabel('Sydney Temp')
plt.show()

# See a sample of raw data
dataset.head()
# Out:
#      DDMMYYYY  MaxTempNewcastleAirport  MaxTempSydneyAirport
# 252  19420910                     18.6                  16.2
# 253  19420911                     18.8                  17.1
# 254  19420912                     18.9                  14.9
# 255  19420913                     19.6                  20.2
# 256  19420914                     23.8                  24.3

# %% [markdown]
# Here's the beginnings of an OOP approach. It plots the existing data in blue and the predicted line in red.

# %%
# Import dependancies 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# Load the dataset
fulldataset = pd.read_csv('../datasets/AirportTemps.csv')
dataset = fulldataset.dropna()

class Model():
    def __init__(self, data):
        self.dataset = data
        self.m = 0
        self.b = 0
        self.learning_rate = .005
        self.cycles = 10

    def plot(self):
        predictions = self.predict()
        plt.scatter(self.dataset['MaxTempNewcastleAirport'],dataset['MaxTempSydneyAirport'],marker='x')
        plt.plot(self.dataset['MaxTempNewcastleAirport'],predictions, 'r')
        plt.ylabel('Sydney Temp')
        plt.show()

    def predict(self, m=None, b=None):
        if not m: 
            m = self.m
        if not b:
            b = self.b
        print(f'predicting with m={m}, and b = {b}')
        predictions = [x * m + b for x in dataset['MaxTempNewcastleAirport']]
        return predictions
    
    def loss(self, m=None, b=None):
        if not m: #This allows us to pass in m and b if desired, using the model's existing m and b as a fallback. 
            m = self.m
        if not b:
            b = self.b
        predictions = self.predict(m=m,b=b)
        loss = self.dataset['MaxTempSydneyAirport'] - predictions
        loss_squared = loss * loss
        mse = loss_squared.mean()
        print(f'Predicted mse={mse}')
        return mse
    
    def decide_on_change_in_b(self):
        current_loss = self.loss()
        random_sign = random.choice([-1, 1]) #Added this so the model also checks if b or m decreasing would make improvements
        delta = current_loss * self.learning_rate
        delta = delta * random_sign
        loss_if_b_increased = self.loss(b=(self.b + delta))
        print(f'Current loss = {current_loss}, loss_if_b_increased = {loss_if_b_increased}')

        if loss_if_b_increased < current_loss:
            print(f'Increase by {delta}')
            return delta
        else:
            return 0
    
    def decide_on_change_in_m(self):
        current_loss = self.loss()
        random_sign = random.choice([-1, 1]) #Added this so the model also checks if b or m decreasing would make improvements
        delta = current_loss * self.learning_rate
        delta = delta * random_sign
        loss_if_m_increased = self.loss(m=(self.m + delta))
        print(f'Current loss = {current_loss}, loss_if_m_increased = {loss_if_m_increased}')

        if loss_if_m_increased < current_loss:
            print(f'Increase by {delta}')
            return delta
        else:
            return 0
    
    
    def train(self):
        for i in range(self.cycles):
            self.plot()
            self.m = self.m + self.decide_on_change_in_m()
            self.b = self.b + self.decide_on_change_in_b()

model = Model(dataset)
model.train()
# Out:
# predicting with m=0, and b = 0
# predicting with m=0, and b = 0
# Predicted mse=531.2686256339159
# predicting with m=-2.6563431281695795, and b = 0
# Predicted mse=7446.658655577907
# Current loss = 531.2686256339159, loss_if_m_increased = 7446.658655577907
# predicting with m=0, and b = 0
# Predicted mse=531.2686256339159
# predicting with m=0, and b = 2.6563431281695795
# Predicted mse=418.694618963668
# Current loss = 531.2686256339159, loss_if_b_increased = 418.694618963668
# Increase by 2.6563431281695795
# predicting with m=0, and b = 2.6563431281695795
# predicting with m=0, and b = 2.6563431281695795
# Predicted mse=418.694618963668
# predicting with m=-2.09347309481834, and b = 2.6563431281695795
# Predicted mse=4941.287535996806
# Current loss = 418.694618963668, loss_if_m_increased = 4941.287535996806
# predicting with m=0, and b = 2.6563431281695795
# Predicted mse=418.694618963668
# predicting with m=0, and b = 4.74981622298792
# Predicted mse=339.91827216117946
# Current loss = 418.694618963668, loss_if_b_increased = 339.91827216117946
# Increase by 2.09347309481834
# predicting with m=0, and b = 4.74981622298792
# predicting with m=0, and b = 4.74981622298792
# Predicted mse=339.91827216117946
# predicting with m=1.6995913608058972, and b = 4.74981622298792
# Predicted mse=494.08713478743664
# Current loss = 339.91827216117946, loss_if_m_increased = 494.08713478743664
# predicting with m=0, and b = 4.74981622298792
# Predicted mse=339.91827216117946
# predicting with m=0, and b = 3.0502248621820227
# Predicted mse=403.20360807676326
# Current loss = 339.91827216117946, loss_if_b_increased = 403.20360807676326
# predicting with m=0, and b = 4.74981622298792
# predicting with m=0, and b = 4.74981622298792
# Predicted mse=339.91827216117946
# predicting with m=-1.6995913608058972, and b = 4.74981622298792
# Predicted mse=3466.1734137633953
# Current loss = 339.91827216117946, loss_if_m_increased = 3466.1734137633953
# predicting with m=0, and b = 4.74981622298792
# Predicted mse=339.91827216117946
# predicting with m=0, and b = 6.449407583793817
# Predicted mse=282.4101578330478
# Current loss = 339.91827216117946, loss_if_b_increased = 282.4101578330478
# Increase by 1.6995913608058972
# predicting with m=0, and b = 6.449407583793817
# predicting with m=0, and b = 6.449407583793817
# Predicted mse=282.4101578330478
# predicting with m=-1.412050789165239, and b = 6.449407583793817
# Predicted mse=2537.714224965739
# Current loss = 282.4101578330478, loss_if_m_increased = 2537.714224965739
# predicting with m=0, and b = 6.449407583793817
# Predicted mse=282.4101578330478
# predicting with m=0, and b = 7.8614583729590555
# Predicted mse=239.02518841183908
# Current loss = 282.4101578330478, loss_if_b_increased = 239.02518841183908
# Increase by 1.412050789165239
# predicting with m=0, and b = 7.8614583729590555
# predicting with m=0, and b = 7.8614583729590555
# Predicted mse=239.02518841183908
# predicting with m=1.1951259420591955, and b = 7.8614583729590555
# Predicted mse=177.86678822720523
# Current loss = 239.02518841183908, loss_if_m_increased = 177.86678822720523
# Increase by 1.1951259420591955
# predicting with m=1.1951259420591955, and b = 7.8614583729590555
# Predicted mse=177.86678822720523
# predicting with m=1.1951259420591955, and b = 8.750792314095081
# Predicted mse=201.9683735141157
# Current loss = 177.86678822720523, loss_if_b_increased = 201.9683735141157
# predicting with m=1.1951259420591955, and b = 7.8614583729590555
# predicting with m=1.1951259420591955, and b = 7.8614583729590555
# Predicted mse=177.86678822720523
# predicting with m=0.3057920009231694, and b = 7.8614583729590555
# Predicted mse=68.9574084030608
# Current loss = 177.86678822720523, loss_if_m_increased = 68.9574084030608
# Increase by -0.8893339411360262
# predicting with m=0.3057920009231694, and b = 7.8614583729590555
# Predicted mse=68.9574084030608
# predicting with m=0.3057920009231694, and b = 7.516671330943751
# Predicted mse=74.28464369426905
# Current loss = 68.9574084030608, loss_if_b_increased = 74.28464369426905
# predicting with m=0.3057920009231694, and b = 7.8614583729590555
# predicting with m=0.3057920009231694, and b = 7.8614583729590555
# Predicted mse=68.9574084030608
# predicting with m=0.6505790429384734, and b = 7.8614583729590555
# Predicted mse=4.5708159302004665
# Current loss = 68.9574084030608, loss_if_m_increased = 4.5708159302004665
# Increase by 0.34478704201530397
# predicting with m=0.6505790429384734, and b = 7.8614583729590555
# Predicted mse=4.5708159302004665
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# Predicted mse=4.550486584929369
# Current loss = 4.5708159302004665, loss_if_b_increased = 4.550486584929369
# Increase by -0.02285407965100233
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# Predicted mse=4.550486584929369
# predicting with m=0.6733314758631201, and b = 7.8386042933080535
# Predicted mse=5.025820090331222
# Current loss = 4.550486584929369, loss_if_m_increased = 5.025820090331222
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# Predicted mse=4.550486584929369
# predicting with m=0.6505790429384734, and b = 7.8613567262327
# Predicted mse=4.570723199874238
# Current loss = 4.550486584929369, loss_if_b_increased = 4.570723199874238
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# Predicted mse=4.550486584929369
# predicting with m=0.6278266100138266, and b = 7.8386042933080535
# Predicted mse=4.663043842936997
# Current loss = 4.550486584929369, loss_if_m_increased = 4.663043842936997
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# Predicted mse=4.550486584929369
# predicting with m=0.6505790429384734, and b = 7.8613567262327
# Predicted mse=4.570723199874238
# Current loss = 4.550486584929369, loss_if_b_increased = 4.570723199874238
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# Predicted mse=4.550486584929369
# predicting with m=0.6278266100138266, and b = 7.8386042933080535
# Predicted mse=4.663043842936997
# Current loss = 4.550486584929369, loss_if_m_increased = 4.663043842936997
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# Predicted mse=4.550486584929369
# predicting with m=0.6505790429384734, and b = 7.8613567262327
# Predicted mse=4.570723199874238
# Current loss = 4.550486584929369, loss_if_b_increased = 4.570723199874238
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# Predicted mse=4.550486584929369
# predicting with m=0.6278266100138266, and b = 7.8386042933080535
# Predicted mse=4.663043842936997
# Current loss = 4.550486584929369, loss_if_m_increased = 4.663043842936997
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# Predicted mse=4.550486584929369
# predicting with m=0.6505790429384734, and b = 7.8613567262327
# Predicted mse=4.570723199874238
# Current loss = 4.550486584929369, loss_if_b_increased = 4.570723199874238
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# Predicted mse=4.550486584929369
# predicting with m=0.6278266100138266, and b = 7.8386042933080535
# Predicted mse=4.663043842936997
# Current loss = 4.550486584929369, loss_if_m_increased = 4.663043842936997
# predicting with m=0.6505790429384734, and b = 7.8386042933080535
# Predicted mse=4.550486584929369
# predicting with m=0.6505790429384734, and b = 7.815851860383407
# Predicted mse=4.5312853163924816
# Current loss = 4.550486584929369, loss_if_b_increased = 4.5312853163924816
# Increase by -0.022752432924646845
# predicting with m=0.6505790429384734, and b = 7.815851860383407
# predicting with m=0.6505790429384734, and b = 7.815851860383407
# Predicted mse=4.5312853163924816
# predicting with m=0.6732354695204358, and b = 7.815851860383407
# Predicted mse=4.979429005240287
# Current loss = 4.5312853163924816, loss_if_m_increased = 4.979429005240287
# predicting with m=0.6505790429384734, and b = 7.815851860383407
# Predicted mse=4.5312853163924816
# predicting with m=0.6505790429384734, and b = 7.793195433801444
# Predicted mse=4.51319387216903
# Current loss = 4.5312853163924816, loss_if_b_increased = 4.51319387216903
# Increase by -0.02265642658196241
# predicting with m=0.6505790429384734, and b = 7.793195433801444
# predicting with m=0.6505790429384734, and b = 7.793195433801444
# Predicted mse=4.51319387216903
# predicting with m=0.6731450122993184, and b = 7.793195433801444
# Predicted mse=4.9346365274958135
# Current loss = 4.51319387216903, loss_if_m_increased = 4.9346365274958135
# predicting with m=0.6505790429384734, and b = 7.793195433801444
# Predicted mse=4.51319387216903
# predicting with m=0.6505790429384734, and b = 7.770629464440599
# Predicted mse=4.49619514638616
# Current loss = 4.51319387216903, loss_if_b_increased = 4.49619514638616
# Increase by -0.022565969360845147
# predicting with m=0.6505790429384734, and b = 7.770629464440599
# predicting with m=0.6505790429384734, and b = 7.770629464440599
# Predicted mse=4.49619514638616
# predicting with m=0.6280980672065426, and b = 7.770629464440599
# Predicted mse=4.674939882014106
# Current loss = 4.49619514638616, loss_if_m_increased = 4.674939882014106
# predicting with m=0.6505790429384734, and b = 7.770629464440599
# Predicted mse=4.49619514638616
# predicting with m=0.6505790429384734, and b = 7.748148488708669
# Predicted mse=4.480273144758768
# Current loss = 4.49619514638616, loss_if_b_increased = 4.480273144758768
# Increase by -0.0224809757319308
# predicting with m=0.6505790429384734, and b = 7.748148488708669
# predicting with m=0.6505790429384734, and b = 7.748148488708669
# Predicted mse=4.480273144758768
# predicting with m=0.6729804086622672, and b = 7.748148488708669
# Predicted mse=4.849665718975238
# Current loss = 4.480273144758768, loss_if_m_increased = 4.849665718975238
# predicting with m=0.6505790429384734, and b = 7.748148488708669
# Predicted mse=4.480273144758768
# predicting with m=0.6505790429384734, and b = 7.725747122984875
# Predicted mse=4.465412952135947
# Current loss = 4.480273144758768, loss_if_b_increased = 4.465412952135947
# Increase by -0.02240136572379384
# predicting with m=0.6505790429384734, and b = 7.725747122984875
# predicting with m=0.6505790429384734, and b = 7.725747122984875
# Predicted mse=4.465412952135947
# predicting with m=0.6282519781777937, and b = 7.725747122984875
# Predicted mse=4.68753865356068
# Current loss = 4.465412952135947, loss_if_m_increased = 4.68753865356068
# predicting with m=0.6505790429384734, and b = 7.725747122984875
# Predicted mse=4.465412952135947
# predicting with m=0.6505790429384734, and b = 7.703420058224195
# Predicted mse=4.451600702439232
# Current loss = 4.465412952135947, loss_if_b_increased = 4.451600702439232
# Increase by -0.022327064760679735
# predicting with m=0.6505790429384734, and b = 7.703420058224195
# predicting with m=0.6505790429384734, and b = 7.703420058224195
# Predicted mse=4.451600702439232
# predicting with m=0.6728370464506696, and b = 7.703420058224195
# Predicted mse=4.770564594885474
# Current loss = 4.451600702439232, loss_if_m_increased = 4.770564594885474
# predicting with m=0.6505790429384734, and b = 7.703420058224195
# Predicted mse=4.451600702439232
# predicting with m=0.6505790429384734, and b = 7.7256780617363905
# Predicted mse=4.465368691432046
# Current loss = 4.451600702439232, loss_if_b_increased = 4.465368691432046
# predicting with m=0.6505790429384734, and b = 7.703420058224195
# predicting with m=0.6505790429384734, and b = 7.703420058224195
# Predicted mse=4.451600702439232
# predicting with m=0.6728370464506696, and b = 7.703420058224195
# Predicted mse=4.770564594885474
# Current loss = 4.451600702439232, loss_if_m_increased = 4.770564594885474
# predicting with m=0.6505790429384734, and b = 7.703420058224195
# Predicted mse=4.451600702439232
# predicting with m=0.6505790429384734, and b = 7.7256780617363905
# Predicted mse=4.465368691432046
# Current loss = 4.451600702439232, loss_if_b_increased = 4.465368691432046
# predicting with m=0.6505790429384734, and b = 7.703420058224195
# predicting with m=0.6505790429384734, and b = 7.703420058224195
# Predicted mse=4.451600702439232
# predicting with m=0.6283210394262772, and b = 7.703420058224195
# Predicted mse=4.6952544758642984
# Current loss = 4.451600702439232, loss_if_m_increased = 4.6952544758642984
# predicting with m=0.6505790429384734, and b = 7.703420058224195
# Predicted mse=4.451600702439232
# predicting with m=0.6505790429384734, and b = 7.681162054711999
# Predicted mse=4.438823550887117
# Current loss = 4.451600702439232, loss_if_b_increased = 4.438823550887117
# Increase by -0.022258003512196162
# predicting with m=0.6505790429384734, and b = 7.681162054711999
# predicting with m=0.6505790429384734, and b = 7.681162054711999
# Predicted mse=4.438823550887117
# predicting with m=0.6727731606929089, and b = 7.681162054711999
# Predicted mse=4.733116336535273
# Current loss = 4.438823550887117, loss_if_m_increased = 4.733116336535273
# predicting with m=0.6505790429384734, and b = 7.681162054711999
# Predicted mse=4.438823550887117
# predicting with m=0.6505790429384734, and b = 7.703356172466434
# Predicted mse=4.451562611090867
# Current loss = 4.438823550887117, loss_if_b_increased = 4.451562611090867
# predicting with m=0.6505790429384734, and b = 7.681162054711999
# predicting with m=0.6505790429384734, and b = 7.681162054711999
# Predicted mse=4.438823550887117
# predicting with m=0.6727731606929089, and b = 7.681162054711999
# Predicted mse=4.733116336535273
# Current loss = 4.438823550887117, loss_if_m_increased = 4.733116336535273
# predicting with m=0.6505790429384734, and b = 7.681162054711999
# Predicted mse=4.438823550887117
# predicting with m=0.6505790429384734, and b = 7.658967936957564
# Predicted mse=4.427069648409164
# Current loss = 4.438823550887117, loss_if_b_increased = 4.427069648409164
# Increase by -0.022194117754435586
# predicting with m=0.6505790429384734, and b = 7.658967936957564
# predicting with m=0.6505790429384734, and b = 7.658967936957564
# Predicted mse=4.427069648409164
# predicting with m=0.6727143911805191, and b = 7.658967936957564
# Predicted mse=4.697020457719322
# Current loss = 4.427069648409164, loss_if_m_increased = 4.697020457719322
# predicting with m=0.6505790429384734, and b = 7.658967936957564
# Predicted mse=4.427069648409164
# predicting with m=0.6505790429384734, and b = 7.636832588715518
# Predicted mse=4.416328118161339
# Current loss = 4.427069648409164, loss_if_b_increased = 4.416328118161339
# Increase by -0.02213534824204582
# predicting with m=0.6505790429384734, and b = 7.636832588715518
# predicting with m=0.6505790429384734, and b = 7.636832588715518
# Predicted mse=4.416328118161339
# predicting with m=0.6726606835292801, and b = 7.636832588715518
# Predicted mse=4.662242171391912
# Current loss = 4.416328118161339, loss_if_m_increased = 4.662242171391912
# predicting with m=0.6505790429384734, and b = 7.636832588715518
# Predicted mse=4.416328118161339
# predicting with m=0.6505790429384734, and b = 7.614750948124711
# Predicted mse=4.406589034062006
# Current loss = 4.416328118161339, loss_if_b_increased = 4.406589034062006
# Increase by -0.0220816405908067
# predicting with m=0.6505790429384734, and b = 7.614750948124711
# predicting with m=0.6505790429384734, and b = 7.614750948124711
# Predicted mse=4.406589034062006
# predicting with m=0.6726119881087834, and b = 7.614750948124711
# Predicted mse=4.628748265964294
# Current loss = 4.406589034062006, loss_if_m_increased = 4.628748265964294
# predicting with m=0.6505790429384734, and b = 7.614750948124711
# Predicted mse=4.406589034062006
# predicting with m=0.6505790429384734, and b = 7.592718002954401
# Predicted mse=4.397843401275384
# Current loss = 4.406589034062006, loss_if_b_increased = 4.397843401275384
# Increase by -0.02203294517031003
# predicting with m=0.6505790429384734, and b = 7.592718002954401
# predicting with m=0.6505790429384734, and b = 7.592718002954401
# Predicted mse=4.397843401275384
# predicting with m=0.6285898259320964, and b = 7.592718002954401
# Predicted mse=4.748291193858427
# Current loss = 4.397843401275384, loss_if_m_increased = 4.748291193858427
# predicting with m=0.6505790429384734, and b = 7.592718002954401
# Predicted mse=4.397843401275384
# predicting with m=0.6505790429384734, and b = 7.614707219960778
# Predicted mse=4.40657071530356
# Current loss = 4.397843401275384, loss_if_b_increased = 4.40657071530356
# predicting with m=0.6505790429384734, and b = 7.592718002954401
# predicting with m=0.6505790429384734, and b = 7.592718002954401
# Predicted mse=4.397843401275384
# predicting with m=0.6285898259320964, and b = 7.592718002954401
# Predicted mse=4.748291193858427
# Current loss = 4.397843401275384, loss_if_m_increased = 4.748291193858427
# predicting with m=0.6505790429384734, and b = 7.592718002954401
# Predicted mse=4.397843401275384
# predicting with m=0.6505790429384734, and b = 7.614707219960778
# Predicted mse=4.40657071530356
# Current loss = 4.397843401275384, loss_if_b_increased = 4.40657071530356
# predicting with m=0.6505790429384734, and b = 7.592718002954401
# predicting with m=0.6505790429384734, and b = 7.592718002954401
# Predicted mse=4.397843401275384
# predicting with m=0.6725682599448503, and b = 7.592718002954401
# Predicted mse=4.59650703627097
# Current loss = 4.397843401275384, loss_if_m_increased = 4.59650703627097
# predicting with m=0.6505790429384734, and b = 7.592718002954401
# Predicted mse=4.397843401275384
# predicting with m=0.6505790429384734, and b = 7.570728785948024
# Predicted mse=4.390083138576315
# Current loss = 4.397843401275384, loss_if_b_increased = 4.390083138576315
# Increase by -0.02198921700637692
# predicting with m=0.6505790429384734, and b = 7.570728785948024
# predicting with m=0.6505790429384734, and b = 7.570728785948024
# Predicted mse=4.390083138576315
# predicting with m=0.6286286272455918, and b = 7.570728785948024
# Predicted mse=4.761853314924012
# Current loss = 4.390083138576315, loss_if_m_increased = 4.761853314924012
# predicting with m=0.6505790429384734, and b = 7.570728785948024
# Predicted mse=4.390083138576315
# predicting with m=0.6505790429384734, and b = 7.5487783702551425
# Predicted mse=4.383301062536853
# Current loss = 4.390083138576315, loss_if_b_increased = 4.383301062536853
# Increase by -0.021950415692881572
# predicting with m=0.6505790429384734, and b = 7.5487783702551425
# predicting with m=0.6505790429384734, and b = 7.5487783702551425
# Predicted mse=4.383301062536853
# predicting with m=0.6724955482511576, and b = 7.5487783702551425
# Predicted mse=4.535662928188484
# Current loss = 4.383301062536853, loss_if_m_increased = 4.535662928188484
# predicting with m=0.6505790429384734, and b = 7.5487783702551425
# Predicted mse=4.383301062536853
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# Predicted mse=4.377490873481502
# Current loss = 4.383301062536853, loss_if_b_increased = 4.377490873481502
# Increase by -0.021916505312684267
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# Predicted mse=4.377490873481502
# predicting with m=0.6724664973058808, and b = 7.526861864942458
# Predicted mse=4.507003603057645
# Current loss = 4.377490873481502, loss_if_m_increased = 4.507003603057645
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# Predicted mse=4.377490873481502
# predicting with m=0.6505790429384734, and b = 7.548749319309866
# Predicted mse=4.383292725116322
# Current loss = 4.377490873481502, loss_if_b_increased = 4.383292725116322
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# Predicted mse=4.377490873481502
# predicting with m=0.6286915885710659, and b = 7.526861864942458
# Predicted mse=4.792018929062777
# Current loss = 4.377490873481502, loss_if_m_increased = 4.792018929062777
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# Predicted mse=4.377490873481502
# predicting with m=0.6505790429384734, and b = 7.548749319309866
# Predicted mse=4.383292725116322
# Current loss = 4.377490873481502, loss_if_b_increased = 4.383292725116322
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# Predicted mse=4.377490873481502
# predicting with m=0.6286915885710659, and b = 7.526861864942458
# Predicted mse=4.792018929062777
# Current loss = 4.377490873481502, loss_if_m_increased = 4.792018929062777
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# Predicted mse=4.377490873481502
# predicting with m=0.6505790429384734, and b = 7.548749319309866
# Predicted mse=4.383292725116322
# Current loss = 4.377490873481502, loss_if_b_increased = 4.383292725116322
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# Predicted mse=4.377490873481502
# predicting with m=0.6724664973058808, and b = 7.526861864942458
# Predicted mse=4.507003603057645
# Current loss = 4.377490873481502, loss_if_m_increased = 4.507003603057645
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# Predicted mse=4.377490873481502
# predicting with m=0.6505790429384734, and b = 7.548749319309866
# Predicted mse=4.383292725116322
# Current loss = 4.377490873481502, loss_if_b_increased = 4.383292725116322
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# Predicted mse=4.377490873481502
# predicting with m=0.6724664973058808, and b = 7.526861864942458
# Predicted mse=4.507003603057645
# Current loss = 4.377490873481502, loss_if_m_increased = 4.507003603057645
# predicting with m=0.6505790429384734, and b = 7.526861864942458
# Predicted mse=4.377490873481502
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# Predicted mse=4.37264714316405
# Current loss = 4.377490873481502, loss_if_b_increased = 4.37264714316405
# Increase by -0.02188745436740751
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# Predicted mse=4.37264714316405
# predicting with m=0.6724422786542936, and b = 7.504974410575051
# Predicted mse=4.47948394716173
# Current loss = 4.37264714316405, loss_if_m_increased = 4.47948394716173
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# Predicted mse=4.37264714316405
# predicting with m=0.6505790429384734, and b = 7.526837646290871
# Predicted mse=4.377484984355245
# Current loss = 4.37264714316405, loss_if_b_increased = 4.377484984355245
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# Predicted mse=4.37264714316405
# predicting with m=0.6724422786542936, and b = 7.504974410575051
# Predicted mse=4.47948394716173
# Current loss = 4.37264714316405, loss_if_m_increased = 4.47948394716173
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# Predicted mse=4.37264714316405
# predicting with m=0.6505790429384734, and b = 7.526837646290871
# Predicted mse=4.377484984355245
# Current loss = 4.37264714316405, loss_if_b_increased = 4.377484984355245
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# Predicted mse=4.37264714316405
# predicting with m=0.6287158072226531, and b = 7.504974410575051
# Predicted mse=4.80864781905465
# Current loss = 4.37264714316405, loss_if_m_increased = 4.80864781905465
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# Predicted mse=4.37264714316405
# predicting with m=0.6505790429384734, and b = 7.526837646290871
# Predicted mse=4.377484984355245
# Current loss = 4.37264714316405, loss_if_b_increased = 4.377484984355245
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# Predicted mse=4.37264714316405
# predicting with m=0.6287158072226531, and b = 7.504974410575051
# Predicted mse=4.80864781905465
# Current loss = 4.37264714316405, loss_if_m_increased = 4.80864781905465
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# Predicted mse=4.37264714316405
# predicting with m=0.6505790429384734, and b = 7.526837646290871
# Predicted mse=4.377484984355245
# Current loss = 4.37264714316405, loss_if_b_increased = 4.377484984355245
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# Predicted mse=4.37264714316405
# predicting with m=0.6724422786542936, and b = 7.504974410575051
# Predicted mse=4.47948394716173
# Current loss = 4.37264714316405, loss_if_m_increased = 4.47948394716173
# predicting with m=0.6505790429384734, and b = 7.504974410575051
# Predicted mse=4.37264714316405
# predicting with m=0.6505790429384734, and b = 7.483111174859231
# Predicted mse=4.368765304124787
# Current loss = 4.37264714316405, loss_if_b_increased = 4.368765304124787
# Increase by -0.021863235715820252
# predicting with m=0.6505790429384734, and b = 7.483111174859231
# predicting with m=0.6505790429384734, and b = 7.483111174859231
# Predicted mse=4.368765304124787
# predicting with m=0.6724228694590972, and b = 7.483111174859231
# Predicted mse=4.453078879482094
# Current loss = 4.368765304124787, loss_if_m_increased = 4.453078879482094
# predicting with m=0.6505790429384734, and b = 7.483111174859231
# Predicted mse=4.368765304124787
# predicting with m=0.6505790429384734, and b = 7.461267348338607
# Predicted mse=4.365841640692471
# Current loss = 4.368765304124787, loss_if_b_increased = 4.365841640692471
# Increase by -0.021843826520623937
# predicting with m=0.6505790429384734, and b = 7.461267348338607
# predicting with m=0.6505790429384734, and b = 7.461267348338607
# Predicted mse=4.365841640692471
# predicting with m=0.628749834735011, and b = 7.461267348338607
# Predicted mse=4.845067868135411
# Current loss = 4.365841640692471, loss_if_m_increased = 4.845067868135411
# predicting with m=0.6505790429384734, and b = 7.461267348338607
# Predicted mse=4.365841640692471
# predicting with m=0.6505790429384734, and b = 7.439438140135144
# Predicted mse=4.363873281600937
# Current loss = 4.365841640692471, loss_if_b_increased = 4.363873281600937
# Increase by -0.021829208203462357
# predicting with m=0.6505790429384734, and b = 7.439438140135144
# predicting with m=0.6505790429384734, and b = 7.439438140135144
# Predicted mse=4.363873281600937
# predicting with m=0.6287596765304687, and b = 7.439438140135144
# Predicted mse=4.864889818507865
# Current loss = 4.363873281600937, loss_if_m_increased = 4.864889818507865
# predicting with m=0.6505790429384734, and b = 7.439438140135144
# Predicted mse=4.363873281600937
# predicting with m=0.6505790429384734, and b = 7.417618773727139
# Predicted mse=4.362858194195478
# Current loss = 4.363873281600937, loss_if_b_increased = 4.362858194195478
# Increase by -0.021819366408004685
# predicting with m=0.6505790429384734, and b = 7.417618773727139
# predicting with m=0.6505790429384734, and b = 7.417618773727139
# Predicted mse=4.362858194195478
# predicting with m=0.6287647519674959, and b = 7.417618773727139
# Predicted mse=4.885808505304332
# Current loss = 4.362858194195478, loss_if_m_increased = 4.885808505304332
# predicting with m=0.6505790429384734, and b = 7.417618773727139
# Predicted mse=4.362858194195478
# predicting with m=0.6505790429384734, and b = 7.395804482756162
# Predicted mse=4.362795180209282
# Current loss = 4.362858194195478, loss_if_b_increased = 4.362795180209282
# Increase by -0.02181429097097739
# predicting with m=0.6505790429384734, and b = 7.395804482756162
# predicting with m=0.6505790429384734, and b = 7.395804482756162
# Predicted mse=4.362795180209282
# predicting with m=0.6723930188395197, and b = 7.395804482756162
# Predicted mse=4.358142717357769
# Current loss = 4.362795180209282, loss_if_m_increased = 4.358142717357769
# Increase by 0.021813975901046414
# predicting with m=0.6723930188395197, and b = 7.395804482756162
# Predicted mse=4.358142717357769
# predicting with m=0.6723930188395197, and b = 7.374013769169373
# Predicted mse=4.3369461294243346
# Current loss = 4.358142717357769, loss_if_b_increased = 4.3369461294243346
# Increase by -0.021790713586788843
# predicting with m=0.6723930188395197, and b = 7.374013769169373
# predicting with m=0.6723930188395197, and b = 7.374013769169373
# Predicted mse=4.3369461294243346
# predicting with m=0.6507082881923981, and b = 7.374013769169373
# Predicted mse=4.3619326082392424
# Current loss = 4.3369461294243346, loss_if_m_increased = 4.3619326082392424
# predicting with m=0.6723930188395197, and b = 7.374013769169373
# Predicted mse=4.3369461294243346
# predicting with m=0.6723930188395197, and b = 7.395698499816495
# Predicted mse=4.358037325840436
# Current loss = 4.3369461294243346, loss_if_b_increased = 4.358037325840436
# predicting with m=0.6723930188395197, and b = 7.374013769169373
# predicting with m=0.6723930188395197, and b = 7.374013769169373
# Predicted mse=4.3369461294243346
# predicting with m=0.6507082881923981, and b = 7.374013769169373
# Predicted mse=4.3619326082392424
# Current loss = 4.3369461294243346, loss_if_m_increased = 4.3619326082392424
# predicting with m=0.6723930188395197, and b = 7.374013769169373
# Predicted mse=4.3369461294243346
# predicting with m=0.6723930188395197, and b = 7.352329038522251
# Predicted mse=4.316795388094708
# Current loss = 4.3369461294243346, loss_if_b_increased = 4.316795388094708
# Increase by -0.02168473064712167
# predicting with m=0.6723930188395197, and b = 7.352329038522251
# predicting with m=0.6723930188395197, and b = 7.352329038522251
# Predicted mse=4.316795388094708
# predicting with m=0.6508090418990462, and b = 7.352329038522251
# Predicted mse=4.362175658848711
# Current loss = 4.316795388094708, loss_if_m_increased = 4.362175658848711
# predicting with m=0.6723930188395197, and b = 7.352329038522251
# Predicted mse=4.316795388094708
# predicting with m=0.6723930188395197, and b = 7.373913015462725
# Predicted mse=4.336850328422514
# Current loss = 4.316795388094708, loss_if_b_increased = 4.336850328422514
# predicting with m=0.6723930188395197, and b = 7.352329038522251
# predicting with m=0.6723930188395197, and b = 7.352329038522251
# Predicted mse=4.316795388094708
# predicting with m=0.6939769957799933, and b = 7.352329038522251
# Predicted mse=4.800473851042834
# Current loss = 4.316795388094708, loss_if_m_increased = 4.800473851042834
# predicting with m=0.6723930188395197, and b = 7.352329038522251
# Predicted mse=4.316795388094708
# predicting with m=0.6723930188395197, and b = 7.330745061581777
# Predicted mse=4.297672183888038
# Current loss = 4.316795388094708, loss_if_b_increased = 4.297672183888038
# Increase by -0.02158397694047354
